https://shopee.vn/T%E1%BA%A5m-h%E1%BA%AFt-s%C3%A1ng-ph%E1%BA%A3n-quang-2-trong-1-(v%C3%A0ng-%E2%80%93-b%E1%BA%A1c)-i.59156038.9200853323?sp_atk=e212d9cc-a862-442c-8467-0af7709c98e7&xptdk=e212d9cc-a862-442c-8467-0af7709c98e7
https://shopee.vn/Flaycam-M%C3%A1y-Bay-%C4%90i%E1%BB%81u-Khi%E1%BB%83n-T%E1%BB%AB-Xa-E88-Pro-Drone-4K-HD-Camera-K%C3%A9p-C%C3%B3-%C4%90%E1%BB%8Bnh-V%E1%BB%8B-1080P-WiFi-T%E1%BA%B7ng-K%C3%A8m-Pin-D%E1%BB%B1-Ph%C3%B2ng-i.649551581.22368758864?sp_atk=eee89b6e-7066-432a-89e0-51812a1288a9&xptdk=eee89b6e-7066-432a-89e0-51812a1288a9"""

# %%
urls = re.findall(r'(https?://\S+)', text)

# %%
headers_list = [{
	'authority': 'httpbin.org',
	'cache-control': 'max-age=0',
	'sec-ch-ua': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"',
	'sec-ch-ua-mobile': '?0',
	'upgrade-insecure-requests': '1',
	'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36',
	'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
	'sec-fetch-site': 'none',
	'sec-fetch-mode': 'navigate',
	'sec-fetch-user': '?1',
	'sec-fetch-dest': 'document',
	'accept-language': 'en-US,en;q=0.9',
} # , {...}
]
headers = random.choice(headers_list)

# %%
d = {"username": [], "rating": [], "comment": [], "product_name": []}

for url in urls:
    r = re.search(r"i\.(\d+)\.(\d+)", url)
    if r:
        shop_id, item_id = r.groups()
        ratings_url = f"https://shopee.vn/api/v2/item/get_ratings?filter=1&flag=1&itemid={item_id}&limit=20&offset={{offset}}&shopid={shop_id}&type=0"
        offset = 0
        count = 0
        while count < 230:
            data = requests.get(ratings_url.format(offset=offset),headers=headers).json()
            if not data["data"]["ratings"]:
                print("**Không còn dữ liệu mới**")
                break

            for rating in data["data"]["ratings"]:
                if rating["comment"]:  # Kiểm tra bình luận không rỗng
                    # Kiểm tra xem sản phẩm có tồn tại không trước khi truy cập
                    if rating["product_items"]:
                        d["product_name"].append(rating["product_items"][0]["name"])
                    else:
                        d["product_name"].append("Unknown Product")
                    d["username"].append(rating["author_username"])
                    d["rating"].append(rating["rating_star"])
                    d["comment"].append(rating["comment"])

                    # print(rating["product_items"][0]["name"])  # In tên sản phẩm
                    print(rating["author_username"])
                    print(rating["rating_star"])
                    print(rating["comment"])
                    print("-" * 100)

            count += 1
            offset += 20

df = pd.DataFrame(d)
print(df)
df.to_csv("/content/sample_data/data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-7e1ccd095102> in <cell line: 3>()
#      10         while count < 230:
#      11             data = requests.get(ratings_url.format(offset=offset),headers=headers).json()
# ---> 12             if not data["data"]["ratings"]:
#      13                 print("**Không còn dữ liệu mới**")
#      14                 break
#
# KeyError: 'data'

# %%
d = {"username": [], "rating": [], "comment": [], "product_name": []}

for url in urls:
    r = re.search(r"i\.(\d+)\.(\d+)", url)
    if r:
        shop_id, item_id = r.groups()
        ratings_url = f"https://shopee.vn/api/v2/item/get_ratings?filter=1&flag=1&itemid={item_id}&limit=20&offset={{offset}}&shopid={shop_id}&type=0"
        offset = 0
        count = 0
        while count < 230:
            data = requests.get(ratings_url.format(offset=offset),headers=headers).json()
            if not data["data"]["ratings"]:
                print("**Không còn dữ liệu mới**")
                break

            for rating in data["data"]["ratings"]:
                if rating["comment"]:  # Kiểm tra bình luận không rỗng
                    # Kiểm tra xem sản phẩm có tồn tại không trước khi truy cập
                    if rating["product_items"]:
                        d["product_name"].append(rating["product_items"][0]["name"])
                    else:
                        d["product_name"].append("Unknown Product")
                    d["username"].append(rating["author_username"])
                    d["rating"].append(rating["rating_star"])
                    d["comment"].append(rating["comment"])

                    # print(rating["product_items"][0]["name"])  # In tên sản phẩm
                    print(rating["author_username"])
                    print(rating["rating_star"])
                    print(rating["comment"])
                    print("-" * 100)

            count += 1
            offset += 20

df = pd.DataFrame(d)
print(df)
df.to_csv("/content/sample_data/data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-7e1ccd095102> in <cell line: 3>()
#      10         while count < 230:
#      11             data = requests.get(ratings_url.format(offset=offset),headers=headers).json()
# ---> 12             if not data["data"]["ratings"]:
#      13                 print("**Không còn dữ liệu mới**")
#      14                 break
#
# KeyError: 'data'

# %%
url = "https://shopee.vn/%C3%81o-Polo-ph%E1%BB%91i-Local-Brand-Morpheus-Unisex-Nam-N%E1%BB%AF-Oversize-Raglan-Polo-i.59676629.24054404508?sp_atk=8288e851-af6d-41a4-bdf6-0c5a388f66e5&xptdk=8288e851-af6d-41a4-bdf6-0c5a388f66e5"

# %%
r = re.search(r"i\.(\d+)\.(\d+)", url)
shop_id, item_id = r.groups()
print(f"{shop_id}, {item_id}")
ratings_url = f"https://shopee.vn/api/v2/item/get_ratings?filter=1&flag=1&itemid={item_id}&limit=20&offset={{offset}}&shopid={shop_id}&type=0"
offset = 0
is_running = True
while is_running:
    data = requests.get(ratings_url.format(offset=offset), headers=headers).json()
    if not data["data"]["ratings"]:
        print("**Không còn dữ liệu mới**")
        break

    for rating in data["data"]["ratings"]:
        if rating["comment"]:  # Check for non-empty comments
            product_name = rating["product_items"][0]["name"] if rating["product_items"] else "Unknown Product"
            username = rating["author_username"]
            rating_star = rating["rating_star"]
            original_comment = rating["comment"]

            # print(rating["product_items"][0]["name"])  # In tên sản phẩm
            print(rating["author_username"])
            print(rating["rating_star"])
            print(rating["comment"])
            print("-" * 100)


    offset += 20
# Out:
# 59676629, 24054404508
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-20004b8622bd> in <cell line: 7>()
#       7 while is_running:
#       8     data = requests.get(ratings_url.format(offset=offset), headers=headers).json()
# ----> 9     if not data["data"]["ratings"]:
#      10         print("**Không còn dữ liệu mới**")
#      11         break
#
# KeyError: 'data'
